# %%
from dicompylercore import dicomparser, dvh, dvhcalc, dose
from scipy.integrate import cumulative_trapezoid, trapezoid
import matplotlib.pyplot as plt
import numpy as np 
from pydicom import dcmread
from pydicom.data import get_testdata_file
import scienceplots

plt.style.use("science")

dp = dicomparser.DicomParser("../CTData/RTSTruct.dcm")

# i.e. Get a dict of structure information
structures = dp.GetStructures()

# %%
auc = [[] for i in range(0,7)]
for i in range(1,6):
    plt.figure(figsize=(8,6))
    for j in range(1,8):
        dose_grid= dose.DoseGrid(f"./outputs/job{i}.dcm")
        dose_grid.multiply(1/np.max(dose_grid.dose_grid))
        dose_grid.save_dcm(f"./outputs/job{i}_normalised.dcm")
        calcdvh = dvhcalc.get_dvh("../CTData/RTSTruct.dcm", f"./outputs/job{i}_normalised.dcm", j)
        print(j)
        auc[j - 1].append(trapezoid(calcdvh.relative_volume.counts, calcdvh.bincenters))
        plt.step(
            calcdvh.bincenters,
            calcdvh.relative_volume.counts,
            label=structures[j]["name"]
        )
        print(calcdvh.describe())
    plt.ylim(-1,102)
    plt.legend()
    plt.ylabel(r"Volume / $\%$", fontsize=16)
    plt.xlabel("Dose / arb", fontsize=16)
    plt.savefig(f"./plots/mb_DVH_{i}.png", dpi=300)
    plt.show()

    arr = []

    for k in range(1,5):
        arr.append(dcmread(f"../CTData/CT{k}.dcm").pixel_array)
    arr = np.sum(arr, axis = 0)
    
    fig,ax = plt.subplots(1, figsize=(6,6))
    print(f"{i} MeV")
    ax.imshow(arr, cmap="gray", alpha=1)
    mesh = ax.pcolormesh([i for i in range(128)], [i for i in range(128)], np.flip(np.flip(np.sum(dose_grid.dose_grid, axis=2).T, axis=0), axis=0), alpha=0.5, vmin=0, vmax=1)
    cbar = fig.colorbar(mesh, fraction=0.046, pad=0.04)
    cbar.set_label("Dose", fontsize=16)
    ax.set_xlabel("X pixel", fontsize=16)
    ax.set_ylabel("Y pixel", fontsize=16)
    plt.savefig(f"./plots/dose_in_patient_{i}.png", dpi=300)
    plt.show()
# Out:
# 1
# Structure: GTVp
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    14.08 cm3
# Max Dose:  0.61 Gy
# Min Dose:  0.20 Gy
# Mean Dose: 0.56 Gy
# D100:      0.19 Gy
# D98:       0.21 Gy
# D95:       0.22 Gy
# D2cc:      0.59 Gy
# None
# 2
# Structure: Lung_R
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    292.96 cm3
# Max Dose:  1.01 Gy
# Min Dose:  0.01 Gy
# Mean Dose: 0.14 Gy
# D100:      0.00 Gy
# D98:       0.00 Gy
# D95:       0.00 Gy
# D2cc:      0.74 Gy
# None
# 3
# Structure: BODY
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    2150.08 cm3
# Max Dose:  1.01 Gy
# Min Dose:  0.01 Gy
# Mean Dose: 0.04 Gy
# D100:      0.00 Gy
# D98:       0.00 Gy
# D95:       0.00 Gy
# D2cc:      0.82 Gy
# None
# 4
# Structure: Heart
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    81.44 cm3
# Max Dose:  0.03 Gy
# Min Dose:  0.01 Gy
# Mean Dose: 0.01 Gy
# D100:      0.00 Gy
# D98:       0.00 Gy
# D95:       0.00 Gy
# D2cc:      0.01 Gy
# None
# 5
# Structure: Lung_L
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    312.48 cm3
# Max Dose:  0.00 Gy
# Min Dose:  0.00 Gy
# Mean Dose: 0.00 Gy
# D100:      0.00 Gy
# D98:       0.00 Gy
# D95:       0.00 Gy
# D2cc:      0.00 Gy
# None
# 6
# Structure: SpinalCord
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    1.60 cm3
# Max Dose:  0.00 Gy
# Min Dose:  0.00 Gy
# Mean Dose: 0.00 Gy
# D100:      0.00 Gy
# D98:       0.00 Gy
# D95:       0.00 Gy
# D2cc:      0.00 Gy
# None
# 7
# Structure: PTV
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    32.48 cm3
# Max Dose:  0.61 Gy
# Min Dose:  0.01 Gy
# Mean Dose: 0.39 Gy
# D100:      0.00 Gy
# D98:       0.01 Gy
# D95:       0.01 Gy
# D2cc:      0.59 Gy
# None
# 1 MeV
# 1
# Structure: GTVp
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    14.08 cm3
# Max Dose:  0.63 Gy
# Min Dose:  0.20 Gy
# Mean Dose: 0.57 Gy
# D100:      0.19 Gy
# D98:       0.21 Gy
# D95:       0.23 Gy
# D2cc:      0.60 Gy
# None
# 2
# Structure: Lung_R
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    292.96 cm3
# Max Dose:  1.00 Gy
# Min Dose:  0.01 Gy
# Mean Dose: 0.14 Gy
# D100:      0.00 Gy
# D98:       0.00 Gy
# D95:       0.00 Gy
# D2cc:      0.77 Gy
# None
# 3
# Structure: BODY
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    2150.08 cm3
# Max Dose:  1.00 Gy
# Min Dose:  0.01 Gy
# Mean Dose: 0.04 Gy
# D100:      0.00 Gy
# D98:       0.00 Gy
# D95:       0.00 Gy
# D2cc:      0.85 Gy
# None
# 4
# Structure: Heart
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    81.44 cm3
# Max Dose:  0.03 Gy
# Min Dose:  0.01 Gy
# Mean Dose: 0.01 Gy
# D100:      0.00 Gy
# D98:       0.00 Gy
# D95:       0.00 Gy
# D2cc:      0.01 Gy
# None
# 5
# Structure: Lung_L
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    312.48 cm3
# Max Dose:  0.00 Gy
# Min Dose:  0.00 Gy
# Mean Dose: 0.00 Gy
# D100:      0.00 Gy
# D98:       0.00 Gy
# D95:       0.00 Gy
# D2cc:      0.00 Gy
# None
# 6
# Structure: SpinalCord
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    1.60 cm3
# Max Dose:  0.00 Gy
# Min Dose:  0.00 Gy
# Mean Dose: 0.00 Gy
# D100:      0.00 Gy
# D98:       0.00 Gy
# D95:       0.00 Gy
# D2cc:      0.00 Gy
# None
# 7
# Structure: PTV
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    32.48 cm3
# Max Dose:  0.63 Gy
# Min Dose:  0.01 Gy
# Mean Dose: 0.40 Gy
# D100:      0.00 Gy
# D98:       0.01 Gy
# D95:       0.01 Gy
# D2cc:      0.61 Gy
# None
# 2 MeV
# 1
# Structure: GTVp
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    14.08 cm3
# Max Dose:  0.63 Gy
# Min Dose:  0.20 Gy
# Mean Dose: 0.57 Gy
# D100:      0.19 Gy
# D98:       0.20 Gy
# D95:       0.22 Gy
# D2cc:      0.60 Gy
# None
# 2
# Structure: Lung_R
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    292.96 cm3
# Max Dose:  1.01 Gy
# Min Dose:  0.01 Gy
# Mean Dose: 0.14 Gy
# D100:      0.00 Gy
# D98:       0.00 Gy
# D95:       0.00 Gy
# D2cc:      0.75 Gy
# None
# 3
# Structure: BODY
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    2150.08 cm3
# Max Dose:  1.01 Gy
# Min Dose:  0.01 Gy
# Mean Dose: 0.04 Gy
# D100:      0.00 Gy
# D98:       0.00 Gy
# D95:       0.00 Gy
# D2cc:      0.83 Gy
# None
# 4
# Structure: Heart
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    81.44 cm3
# Max Dose:  0.03 Gy
# Min Dose:  0.01 Gy
# Mean Dose: 0.01 Gy
# D100:      0.00 Gy
# D98:       0.00 Gy
# D95:       0.00 Gy
# D2cc:      0.01 Gy
# None
# 5
# Structure: Lung_L
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    312.48 cm3
# Max Dose:  0.00 Gy
# Min Dose:  0.00 Gy
# Mean Dose: 0.00 Gy
# D100:      0.00 Gy
# D98:       0.00 Gy
# D95:       0.00 Gy
# D2cc:      0.00 Gy
# None
# 6
# Structure: SpinalCord
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    1.60 cm3
# Max Dose:  0.00 Gy
# Min Dose:  0.00 Gy
# Mean Dose: 0.00 Gy
# D100:      0.00 Gy
# D98:       0.00 Gy
# D95:       0.00 Gy
# D2cc:      0.00 Gy
# None
# 7
# Structure: PTV
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    32.48 cm3
# Max Dose:  0.63 Gy
# Min Dose:  0.01 Gy
# Mean Dose: 0.40 Gy
# D100:      0.00 Gy
# D98:       0.01 Gy
# D95:       0.01 Gy
# D2cc:      0.60 Gy
# None
# 3 MeV
# 1
# Structure: GTVp
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    14.08 cm3
# Max Dose:  0.63 Gy
# Min Dose:  0.21 Gy
# Mean Dose: 0.58 Gy
# D100:      0.20 Gy
# D98:       0.21 Gy
# D95:       0.23 Gy
# D2cc:      0.61 Gy
# None
# 2
# Structure: Lung_R
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    292.96 cm3
# Max Dose:  1.01 Gy
# Min Dose:  0.01 Gy
# Mean Dose: 0.14 Gy
# D100:      0.00 Gy
# D98:       0.00 Gy
# D95:       0.00 Gy
# D2cc:      0.76 Gy
# None
# 3
# Structure: BODY
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    2150.08 cm3
# Max Dose:  1.01 Gy
# Min Dose:  0.01 Gy
# Mean Dose: 0.04 Gy
# D100:      0.00 Gy
# D98:       0.00 Gy
# D95:       0.00 Gy
# D2cc:      0.85 Gy
# None
# 4
# Structure: Heart
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    81.44 cm3
# Max Dose:  0.03 Gy
# Min Dose:  0.01 Gy
# Mean Dose: 0.01 Gy
# D100:      0.00 Gy
# D98:       0.00 Gy
# D95:       0.00 Gy
# D2cc:      0.01 Gy
# None
# 5
# Structure: Lung_L
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    312.48 cm3
# Max Dose:  0.00 Gy
# Min Dose:  0.00 Gy
# Mean Dose: 0.00 Gy
# D100:      0.00 Gy
# D98:       0.00 Gy
# D95:       0.00 Gy
# D2cc:      0.00 Gy
# None
# 6
# Structure: SpinalCord
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    1.60 cm3
# Max Dose:  0.00 Gy
# Min Dose:  0.00 Gy
# Mean Dose: 0.00 Gy
# D100:      0.00 Gy
# D98:       0.00 Gy
# D95:       0.00 Gy
# D2cc:      0.00 Gy
# None
# 7
# Structure: PTV
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    32.48 cm3
# Max Dose:  0.63 Gy
# Min Dose:  0.02 Gy
# Mean Dose: 0.40 Gy
# D100:      0.01 Gy
# D98:       0.00 Gy
# D95:       0.00 Gy
# D2cc:      0.61 Gy
# None
# 4 MeV
# 1
# Structure: GTVp
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    14.08 cm3
# Max Dose:  0.63 Gy
# Min Dose:  0.20 Gy
# Mean Dose: 0.57 Gy
# D100:      0.19 Gy
# D98:       0.21 Gy
# D95:       0.22 Gy
# D2cc:      0.61 Gy
# None
# 2
# Structure: Lung_R
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    292.96 cm3
# Max Dose:  1.01 Gy
# Min Dose:  0.01 Gy
# Mean Dose: 0.14 Gy
# D100:      0.00 Gy
# D98:       0.00 Gy
# D95:       0.00 Gy
# D2cc:      0.78 Gy
# None
# 3
# Structure: BODY
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    2150.08 cm3
# Max Dose:  1.01 Gy
# Min Dose:  0.01 Gy
# Mean Dose: 0.04 Gy
# D100:      0.00 Gy
# D98:       0.00 Gy
# D95:       0.00 Gy
# D2cc:      0.85 Gy
# None
# 4
# Structure: Heart
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    81.44 cm3
# Max Dose:  0.03 Gy
# Min Dose:  0.01 Gy
# Mean Dose: 0.01 Gy
# D100:      0.00 Gy
# D98:       0.00 Gy
# D95:       0.00 Gy
# D2cc:      0.01 Gy
# None
# 5
# Structure: Lung_L
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    312.48 cm3
# Max Dose:  0.00 Gy
# Min Dose:  0.00 Gy
# Mean Dose: 0.00 Gy
# D100:      0.00 Gy
# D98:       0.00 Gy
# D95:       0.00 Gy
# D2cc:      0.00 Gy
# None
# 6
# Structure: SpinalCord
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    1.60 cm3
# Max Dose:  0.00 Gy
# Min Dose:  0.00 Gy
# Mean Dose: 0.00 Gy
# D100:      0.00 Gy
# D98:       0.00 Gy
# D95:       0.00 Gy
# D2cc:      0.00 Gy
# None
# 7
# Structure: PTV
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    32.48 cm3
# Max Dose:  0.63 Gy
# Min Dose:  0.01 Gy
# Mean Dose: 0.40 Gy
# D100:      0.00 Gy
# D98:       0.01 Gy
# D95:       0.01 Gy
# D2cc:      0.61 Gy
# None
# 5 MeV

# %%
for structure_id in structures:
    print(structures[structure_id]["name"], np.mean(auc[structure_id - 1]), np.std(auc[structure_id - 1]))
# Out:
# GTVp 56.995454545454535 0.6826831634461844
# Lung_R 14.232222829055157 0.197127915920348
# BODY 4.012300937639528 0.05002224282901138
# Heart 0.5220039292730844 0.003380088513572776
# Lung_L 0.0 0.0
# SpinalCord 0.0 0.0
# PTV 39.61822660098521 0.47898140282881796
